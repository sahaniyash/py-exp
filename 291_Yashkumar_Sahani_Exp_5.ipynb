# %% [markdown]
# # Experiment 5
#
# # Data Structures
#
# # a) Write a menu-driven python code to make a linked-list

# %%
#creating node
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        
#creating linked list        
class LinkedList:
    def __init__(self):
        self.first = None
        self.last = None
        
    #printing list   
    def printList(self):
        node = self.first
        print(" ")
        print("    Printing List")
        print("______________________\n")
        
        llist = []
        
        while node != None:
            llist.append(node.data)
            node = node.next
        if llist:
            print("Linked List:", llist)
        else:
            print("Linked List is Empty!!!")
    
    #add data to linked list
    def add(self, data):
        new_node = Node(data)
        if self.first == None:
            self.first = new_node
        if self.last != None:
            self.last.next = new_node
        self.last = new_node
        
    def size(self):
        current = self.first
        count = 0
        
        while current != None:
            count += 1
            current = current.next
        print("Size of list is:", count)
        print(" ")
            
    #searching element
    def search(self, item):
        current = self.first
        search_item = item
        found = False
        count = 1
        
        while current != None and not found:
            if int(current.data) == int(search_item):
                found = True
                print("Search Node found at position: ", count)
            else:
                current = current.next
                count += 1
            if current == None and found == False:
                print("Search Node", search_item, "Not Found!!!")
                print(" ")
            
    #removing element
    def remove(self, item):
        current = self.first
        previous = None
        delete_item = item
        found = False
       
        while not found:
            if current.data == delete_item:
                found = True
            else:
                previous = current
                current = current.next
       
        if previous == None:
            self.last = current.next()
        else:
            previous.next = current.next
            print("Element Deleted")
            
            
myLList = LinkedList()

menu = {}

menu['1'] = "Add Node"
menu['2'] = "Search Node"
menu['3'] = "Delete Node"
menu['4'] = "Print Linked List"
menu['5'] = "Exit"

while True:
    options = list(menu.keys())
    options.sort()
    print(" ")
    print("    Menu")
    print("____________\n")
    
    for entry in options:
        print(entry, menu[entry])
      
    selection = input("Enter your choice: ")
    
    if selection == '1':
        print("\n    Adding Nodes")
        print("___________________\n")
        length = int(input("Enter Number of Nodes you want to insert: "))
        
        for counter in range(1, length+1):
            item = int(input("Enter the Linked List Element: "))
            myLList.add(item)
            
        myLList.printList()
        myLList.size()
        
    elif selection == '2':
        print("\n    Searching Node")
        print("______________________\n")
        search_element = int(input("Enter Element to be searched: "))
        myLList.search(search_element)
        
    elif selection == '3':
        print("\n    Deleting Node")
        print("_____________________\n")
        delete_element = int(input("Enter the Node Element to be deleted: "))
        myLList.remove(delete_element)
        myLList.printList()
        myLList.size()
        
    elif selection == '4':
        myLList.printList()
        myLList.size()
        
    elif selection == '5':
        break
        
    else:
        print("Unknown Option Selected!!!")

# %% [markdown]
# # Output

# %%
====================== RESTART: D:/Python39/linked_list.py =====================
 
    Menu
____________

1 Add Node
2 Search Node
3 Delete Node
4 Print Linked List
5 Exit
Enter your choice: 1

    Adding Nodes
___________________

Enter Number of Nodes you want to insert: 4
Enter the Linked List Element: 9
Enter the Linked List Element: 2
Enter the Linked List Element: 8
Enter the Linked List Element: 6
 
    Printing List
______________________

Linked List: [9, 2, 8, 6]
Size of list is: 4
 
 
    Menu
____________

1 Add Node
2 Search Node
3 Delete Node
4 Print Linked List
5 Exit
Enter your choice: 2

    Searching Node
______________________

Enter Element to be searched: 8
Search Node found at position:  3
 
    Menu
____________

1 Add Node
2 Search Node
3 Delete Node
4 Print Linked List
5 Exit
Enter your choice: 4
 
    Printing List
______________________

Linked List: [9, 2, 8, 6]
Size of list is: 4
 
 
    Menu
____________

1 Add Node
2 Search Node
3 Delete Node
4 Print Linked List
5 Exit
Enter your choice: 3

    Deleting Node
_____________________

Enter the Node Element to be deleted: 8
Element Deleted
 
    Printing List
______________________

Linked List: [9, 2, 6]
Size of list is: 3
 
 
    Menu
____________

1 Add Node
2 Search Node
3 Delete Node
4 Print Linked List
5 Exit
Enter your choice: 5

# %% [markdown]
# # b) Write a menu driven python code to implement a Stack

# %%
class Stack:
    def __init__(self):
        self.stack = []
        
    def empty(self):
        return len(self.stack) == 0
    
    def push(self, element):
        self.element = element
        self.stack.append(self.element)
        
    def delete(self):
        if self.empty():
            print("\nStack is underflow No element can be popped!!")
        else:
            print("\nElement popped out of the stack is:", self.stack.pop())
            
    def peek(self):
        if self.empty():
            print("\nStack is underflow No element can be peeked!!")
        else:
            print("\nSize of the stack is:", len(self.stack))
            print("Stack elements are:", self.stack, "\n")
            
    def search(self, element):
        self.element = element
        if self.element in self.stack:
            print("\nElement", self.element,"Exist at index:", self.stack.index(self.element))
        else:
            print("\nElement", self.element, "doesn't exist in the stack!!")

st = Stack()

menu = {}

menu['1'] = "PUSH"
menu['2'] = "POP"
menu['3'] = "PEEK"
menu['4'] = "Search"
menu['5'] = "Exit"

while True:
    options = list(menu.keys())
    options.sort()
    print(" ")
    print("    Menu")
    print("____________\n")
    
    for entry in options:
        print(entry, menu[entry])
        
    selection = input("Enter Your choice: ")
    
    if selection == '1':
        element = int(input("Enter Element to be pushed to stack: "))
        st.push(element)
    elif selection == '2':
        st.delete()
    elif selection == '3':
        st.peek()
    elif selection == '4':
        element = int(input("Enter element to be searched: "))
        st.search(element)
    elif selection == '5':
        break
    else:
        print("\nInvalid choice!!")

# %% [markdown]
# # Output

# %%
 ====================== RESTART: D:/Python39/stack.py =====================
    
    Menu
____________

1 PUSH
2 POP
3 PEEK
4 Search
5 Exit
Enter Your choice: 1
Enter Element to be pushed to stack: 5
 
    Menu
____________

1 PUSH
2 POP
3 PEEK
4 Search
5 Exit
Enter Your choice: 1
Enter Element to be pushed to stack: 8
 
    Menu
____________

1 PUSH
2 POP
3 PEEK
4 Search
5 Exit
Enter Your choice: 1
Enter Element to be pushed to stack: 6
 
    Menu
____________

1 PUSH
2 POP
3 PEEK
4 Search
5 Exit
Enter Your choice: 3

Size of the stack is: 3
Stack elements are: [5, 8, 6] 

 
    Menu
____________

1 PUSH
2 POP
3 PEEK
4 Search
5 Exit
Enter Your choice: 4
Enter element to be searched: 6

Element 6 Exist at index: 2
 
    Menu
____________

1 PUSH
2 POP
3 PEEK
4 Search
5 Exit
Enter Your choice: 2

Element popped out of the stack is: 6
 
    Menu
____________

1 PUSH
2 POP
3 PEEK
4 Search
5 Exit
Enter Your choice: 3

Size of the stack is: 2
Stack elements are: [5, 8] 

 
    Menu
____________

1 PUSH
2 POP
3 PEEK
4 Search
5 Exit
Enter Your choice: 5

# %% [markdown]
# # c) Write a menu driven program in python to implement Queue

# %%
class Queue_operations:
    def __init__(self):
        self.queue = []
        
    def empty(self):
        return len(self.queue) == 0
    
    def enQueue(self, element):
        self.element = element
        self.queue.append(self.element)
        
    def deQueue(self):
        if self.empty():
            print("\nQueue is empty!!")
        else:
            print("\nElement dequeued out of the queue is: ", self.queue.pop(0))
            
    def front(self):
        if self.empty():
            print("\nQueue is empty!!")
        else:
            print("\nElement at front is:", self.queue[0])
            
    def search(self, element):
        self.element = element
        if self.element in self.queue:
            print("\nElement", self.element, "exist at:", self.queue.index(self.element))
        else:
            print("\nSearch element doesn't exist in the queue!!")
            
    def display(self):
        if self.empty():
            print("\nQueue is empty!!")
        else:
            print("\nSize of the queue is:", len(self.queue))
            print("Queue elements are:", self.queue)
            
qo = Queue_operations()

menu = {}

menu['1'] = "EnQueue"
menu['2'] = "DeQueue"
menu['3'] = "Front"
menu['4'] = "Search"
menu['5'] = "Display"
menu['6'] = "Exit"

while True:
    options = list(menu.keys())
    options.sort()
    print(" ")
    print("    Menu")
    print("____________\n")
    
    for entry in options:
        print(entry, menu[entry])
        
    selection = input("Enter Your Choice: ")
    
    if selection == '1':
        element = int(input("Enter Element to be enqueued: "))
        qo.enQueue(element)
    elif selection == '2':
        qo.dequeue()
    elif selection == '3':
        qo.front()
    elif selection == '4':
        element = int(input("Enter element to be searched: "))
        qo.search(element)
    elif selection == '5':
        qo.display()
    elif selection == '6':
        break
    else:
        print("\nInvalid Choice!!")

# %% [markdown]
# # Output

# %%
 ====================== RESTART: D:/Python39/queue.py =====================
    
    Menu
____________

1 EnQueue
2 DeQueue
3 Front
4 Search
5 Display
6 Exit
Enter Your Choice: 1
Enter Element to be enqueued: 5
 
    Menu
____________

1 EnQueue
2 DeQueue
3 Front
4 Search
5 Display
6 Exit
Enter Your Choice: 1
Enter Element to be enqueued: 8
 
    Menu
____________

1 EnQueue
2 DeQueue
3 Front
4 Search
5 Display
6 Exit
Enter Your Choice: 1
Enter Element to be enqueued: 6
 
    Menu
____________

1 EnQueue
2 DeQueue
3 Front
4 Search
5 Display
6 Exit
Enter Your Choice: 3

Element at front is: 5

    Menu
____________

1 EnQueue
2 DeQueue
3 Front
4 Search
5 Display
6 Exit
Enter Your Choice: 5

Size of the queue is: 3
Queue elements are: [5, 8, 6]

    Menu
____________

1 EnQueue
2 DeQueue
3 Front
4 Search
5 Display
6 Exit
Enter Your Choice: 2

Element dequeued out of the queue is:  5

    Menu
____________

1 EnQueue
2 DeQueue
3 Front
4 Search
5 Display
6 Exit
Enter Your Choice: 4
Enter element to be searched: 6

Element 6 exist at: 1

    Menu
____________

1 EnQueue
2 DeQueue
3 Front
4 Search
5 Display
6 Exit
Enter Your Choice: 6
